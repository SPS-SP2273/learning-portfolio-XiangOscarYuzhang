# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# # Exercise 1

# %% [markdown]
# Since it is very dangerous wen we directly rename the data files, I decided to have the back up to test my code and then dthe same code on the actual file.

# %%
import shutil
import os

# %%
os.makedirs("data_back_up")  #create a new folder to back up the data since there will be some changing later.

# %%
source_folder = r'C:\Users\oscar\Documents\GitHub\learning-portfolio-XiangOscarYuzhang\files, folders & os  exercises\os-collaboration-exercise-data'
back_up_folder = r'C:\Users\oscar\Documents\GitHub\learning-portfolio-XiangOscarYuzhang\files, folders & os  exercises\data_back_up'
shutil.copytree(source_folder,back_up_folder)
#copy the folder
# Out:
# 'C:\\Users\\oscar\\Documents\\GitHub\\learning-portfolio-XiangOscarYuzhang\\files, folders & os  exercises\\data_back_up'

# %%
deleting_data_path = r'C:\Users\oscar\Documents\GitHub\learning-portfolio-XiangOscarYuzhang\files, folders & os  exercises\data_back_up'

for file in os.listdir(deleting_data_path):  #for loop created to do repeating task
    if file.endswith('.png'): #checking if the file is ending with png
        file_path = os.path.join(deleting_data_path,file) #locate the actual path of that png file
        print(file_path) # testing before remove
        os.remove(file_path) #deleting all the png file
    if file.endswith('.jpg'): #checking if the file is ending with jpg
        file_path = os.path.join(deleting_data_path,file) #locate the actual path of that jpg file
        print(file_path) # testing before remove
        os.remove(file_path) #deleting all the jpg file
    if file.endswith('.pdf'): #checking if the file is ending with pdf
        file_path = os.path.join(deleting_data_path,file) #locate the actual path of that pdf file
        print(file_path) # testing before remove
        os.remove(file_path)
# Out:
# C:\Users\oscar\Documents\GitHub\learning-portfolio-XiangOscarYuzhang\files, folders & os  exercises\data_back_up\apr-01_melbourne.pdf
# C:\Users\oscar\Documents\GitHub\learning-portfolio-XiangOscarYuzhang\files, folders & os  exercises\data_back_up\apr-01_melbourne.png
# C:\Users\oscar\Documents\GitHub\learning-portfolio-XiangOscarYuzhang\files, folders & os  exercises\data_back_up\apr-01_shanghai.png
# C:\Users\oscar\Documents\GitHub\learning-portfolio-XiangOscarYuzhang\files, folders & os  exercises\data_back_up\apr-01_singapore.jpg
# C:\Users\oscar\Documents\GitHub\learning-portfolio-XiangOscarYuzhang\files, folders & os  exercises\data_back_up\apr-02_cairo.jpg
# C:\Users\oscar\Documents\GitHub\learning-portfolio-XiangOscarYuzhang\files, folders & os  exercises\data_back_up\apr-02_jakarta.png
# C:\Users\oscar\Documents\GitHub\learning-portfolio-XiangOscarYuzhang\files, folders & os  exercises\data_back_up\apr-02_karachi.pdf
# ...

# %%
month_mapping = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
}
folder_name = "data_back_up"
file_name = 'oct-08_singapore.txt'
file_path_name = os.path.join(folder_name, file_name)
print(file_path_name)
part = file_name.split('_')
month_e,day = part[0].split('-')
city = part[1].split('.')[0]
extension = part[1].split('.')[1]
print(month_e,day,city)
month_n = month_mapping[month_e]
new_file_name = f"{month_n}-{day}-{city}.{extension}"
print(new_file_name)
# Out:
# data_back_up\oct-08_singapore.txt
# oct 08 singapore
# 10-08-singapore.txt

# %%
def rename_my_file(old_file_name):
    month_mapping = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
    }
    folder_name = "data_back_up"
    #print(path)
    part = old_file_name.split('_')
    month_e,day = part[0].split('-')
    city = part[1].split('.')[0]
    extension = part[1].split('.')[1]
    #print(month_e,day,city)
    month_n = month_mapping[month_e]
    new_file_name = f"{month_n}-{day}-{city}.{extension}"
    return new_file_name

# %%
rename_my_file('oct-08_singapore.txt')
# Out:
# '10-08-singapore.txt'

# %%
rename_my_file('jan-21_singapore.txt')
# Out:
# '01-21-singapore.txt'

# %%
def rename_my_file(old_file_name):
    month_mapping = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
    }
    folder_name = "data_back_up"
    #print(path)
    part = old_file_name.split('_')
    month_e,day = part[0].split('-')
    city = part[1].split('.')[0]
    extension = part[1].split('.')[1]
    #print(month_e,day,city)
    month_n = month_mapping[month_e]
    new_file_name = f"{month_n}-{day}-{city}.{extension}"
    list_file = [old_file_name,new_file_name]
    return list_file

# %%
file_list = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

# %%
for i in file_list:
    rename_my_file(i)
    external_new_file_name = rename_my_file(i)[1]
    external_old_file_name = rename_my_file(i)[0]
    print(f'{external_old_file_name} ----> {external_new_file_name}')
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %%
import glob

# %%
glob.glob('data_back_up\*.txt')
# Out:
# ['data_back_up\\apr-01_melbourne.txt',
#  'data_back_up\\apr-01_shanghai.txt',
#  'data_back_up\\apr-01_singapore.txt',
#  'data_back_up\\apr-02_cairo.txt',
#  'data_back_up\\apr-02_jakarta.txt',
#  'data_back_up\\apr-02_karachi.txt',
#  'data_back_up\\apr-02_shanghai.txt',
#  'data_back_up\\apr-03_manila.txt',
#  'data_back_up\\apr-03_osaka.txt',
#  'data_back_up\\apr-03_singapore.txt',
#  'data_back_up\\apr-03_tokyo.txt',
#  'data_back_up\\apr-04_manila.txt',
#  'data_back_up\\apr-04_melbourne.txt',
#  'data_back_up\\apr-04_shanghai.txt',
#  'data_back_up\\apr-04_singapore.txt',
#  'data_back_up\\apr-05_karachi.txt',
#  'data_back_up\\apr-05_melbourne.txt',
#  'data_back_up\\apr-05_shanghai.txt',
#  'data_back_up\\apr-05_singapore.txt',
#  'data_back_up\\apr-06_cairo.txt',
#  'data_back_up\\apr-06_jakarta.txt',
#  'data_back_up\\apr-06_karachi.txt',
#  'data_back_up\\apr-06_manila.txt',
#  'data_back_up\\apr-07_cairo.txt',
#  'data_back_up\\apr-07_manila.txt',
# ...

# %%
def rename_my_file(old_file_name):
    month_mapping = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
    }
    folder_name = "data_back_up"
    part = old_file_name.split('_')
    month_e,day = part[0].split('-')
    city = part[1].split('.')[0]
    extension = part[1].split('.')[1]
    month_n = month_mapping[month_e]
    new_file_name = f"{month_n}-{day}-{city}.{extension}"
    #os.rename(old_file_name,new_file_name)
    list_file = [old_file_name,new_file_name]
    return list_file

# %%
file_big_list = glob.glob('data_back_up\*.txt')

# %%
for i in file_big_list:
    rename_my_file(os.path.split(i)[-1])
    external_new_file_name = rename_my_file(os.path.split(i)[-1])[1]
    external_old_file_name = rename_my_file(os.path.split(i)[-1])[0]
    external_new_file_path = os.path.join('data_back_up',external_new_file_name)
    external_old_file_path = os.path.join('data_back_up',external_old_file_name)
    print(f'{external_old_file_path} ----> {external_new_file_path}')
    os.rename(external_old_file_path,external_new_file_path)
# Out:
# data_back_up\apr-01_melbourne.txt ----> data_back_up\04-01-melbourne.txt
# data_back_up\apr-01_shanghai.txt ----> data_back_up\04-01-shanghai.txt
# data_back_up\apr-01_singapore.txt ----> data_back_up\04-01-singapore.txt
# data_back_up\apr-02_cairo.txt ----> data_back_up\04-02-cairo.txt
# data_back_up\apr-02_jakarta.txt ----> data_back_up\04-02-jakarta.txt
# data_back_up\apr-02_karachi.txt ----> data_back_up\04-02-karachi.txt
# data_back_up\apr-02_shanghai.txt ----> data_back_up\04-02-shanghai.txt
# data_back_up\apr-03_manila.txt ----> data_back_up\04-03-manila.txt
# data_back_up\apr-03_osaka.txt ----> data_back_up\04-03-osaka.txt
# data_back_up\apr-03_singapore.txt ----> data_back_up\04-03-singapore.txt
# data_back_up\apr-03_tokyo.txt ----> data_back_up\04-03-tokyo.txt
# data_back_up\apr-04_manila.txt ----> data_back_up\04-04-manila.txt
# data_back_up\apr-04_melbourne.txt ----> data_back_up\04-04-melbourne.txt
# data_back_up\apr-04_shanghai.txt ----> data_back_up\04-04-shanghai.txt
# ...

# %%
city_list = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

# %%
for city in city_list:
    path = os.path.join("data_back_up",city)
    print(path)
    os.mkdir(path)
# Out:
# data_back_up\Cairo
# data_back_up\Dhaka
# data_back_up\Jakarta
# data_back_up\Karachi
# data_back_up\Manila
# data_back_up\Melbourne
# data_back_up\Osaka
# data_back_up\Shanghai
# data_back_up\Singapore
# data_back_up\Tokyo

# %%
cairo_list = glob.glob("data_back_up\*Cairo.txt")

# %%
glob.glob("data_back_up\*Cairo.txt")
# Out:
# ['data_back_up\\01-02-cairo.txt',
#  'data_back_up\\01-03-cairo.txt',
#  'data_back_up\\01-04-cairo.txt',
#  'data_back_up\\01-05-cairo.txt',
#  'data_back_up\\01-07-cairo.txt',
#  'data_back_up\\01-08-cairo.txt',
#  'data_back_up\\01-09-cairo.txt',
#  'data_back_up\\01-11-cairo.txt',
#  'data_back_up\\01-12-cairo.txt',
#  'data_back_up\\01-13-cairo.txt',
#  'data_back_up\\01-15-cairo.txt',
#  'data_back_up\\01-16-cairo.txt',
#  'data_back_up\\01-19-cairo.txt',
#  'data_back_up\\01-20-cairo.txt',
#  'data_back_up\\01-21-cairo.txt',
#  'data_back_up\\01-23-cairo.txt',
#  'data_back_up\\01-27-cairo.txt',
#  'data_back_up\\01-30-cairo.txt',
#  'data_back_up\\02-10-cairo.txt',
#  'data_back_up\\02-17-cairo.txt',
#  'data_back_up\\02-20-cairo.txt',
#  'data_back_up\\02-22-cairo.txt',
#  'data_back_up\\02-25-cairo.txt',
#  'data_back_up\\02-26-cairo.txt',
#  'data_back_up\\03-05-cairo.txt',
#  'data_back_up\\03-06-cairo.txt',
#  'data_back_up\\03-12-cairo.txt',
# ...

# %%
cairo_folder = glob.glob('*\Cairo')[0]
print(cairo_folder)
# Out:
# data_back_up\Cairo

# %%
import shutil

# %%
for i in cairo_list:
    print(f'copy {i} to {cairo_folder}')
    shutil.move(i,cairo_folder)
# Out:
# copy data_back_up\01-02-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-03-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-04-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-05-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-07-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-08-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-09-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-11-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-12-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-13-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-15-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-16-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-19-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-20-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-21-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-23-cairo.txt to data_back_up\Cairo
# copy data_back_up\01-27-cairo.txt to data_back_up\Cairo
# ...

# %%
city_variables = {}
for city in city_list:
    city_variables[city] = glob.glob(f"data_back_up\*{city}.txt")
    for i in city_variables[city]:
        print(f'copy {i} to {city}')
# Out:
# copy data_back_up\01-02-cairo.txt to Cairo
# copy data_back_up\01-03-cairo.txt to Cairo
# copy data_back_up\01-04-cairo.txt to Cairo
# copy data_back_up\01-05-cairo.txt to Cairo
# copy data_back_up\01-07-cairo.txt to Cairo
# copy data_back_up\01-08-cairo.txt to Cairo
# copy data_back_up\01-09-cairo.txt to Cairo
# copy data_back_up\01-11-cairo.txt to Cairo
# copy data_back_up\01-12-cairo.txt to Cairo
# copy data_back_up\01-13-cairo.txt to Cairo
# copy data_back_up\01-15-cairo.txt to Cairo
# copy data_back_up\01-16-cairo.txt to Cairo
# copy data_back_up\01-19-cairo.txt to Cairo
# copy data_back_up\01-20-cairo.txt to Cairo
# copy data_back_up\01-21-cairo.txt to Cairo
# copy data_back_up\01-23-cairo.txt to Cairo
# copy data_back_up\01-27-cairo.txt to Cairo
# copy data_back_up\01-30-cairo.txt to Cairo
# copy data_back_up\02-10-cairo.txt to Cairo
# copy data_back_up\02-17-cairo.txt to Cairo
# copy data_back_up\02-20-cairo.txt to Cairo
# copy data_back_up\02-22-cairo.txt to Cairo
# ...

# %%
city_variables = {}
for city in city_list:
    city_variables[city] = glob.glob(f"data_back_up\*{city}.txt")
    city_path = os.path.join("data_back_up",city)
    for i in city_variables[city]:
        shutil.move(i,city_path)

# %% [markdown]
# ## The scenario

# %% [markdown]
# ## Task 1

# %%
month_mapping = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
}
folder_name = "os-collaboration-exercise-data"
file_name = 'oct-08_singapore.txt'
file_path_name = os.path.join(folder_name, file_name)
print(file_path_name)
part = file_name.split('_')
month_e,day = part[0].split('-')
city = part[1].split('.')[0]
extension = part[1].split('.')[1]
print(month_e,day,city)
month_n = month_mapping[month_e]
new_file_name = f"{month_n}-{day}-{city}.{extension}"
print(new_file_name)
# Out:
# os-collaboration-exercise-data\oct-08_singapore.txt
# oct 08 singapore
# 10-08-singapore.txt

# %% [markdown]
# ## Task 2

# %%
def rename_my_file(old_file_name):
    month_mapping = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
    }
    folder_name = "os-collaboration-exercise-data"
    part = old_file_name.split('_')
    month_e,day = part[0].split('-')
    city = part[1].split('.')[0]
    extension = part[1].split('.')[1]
    #print(month_e,day,city)
    month_n = month_mapping[month_e]
    new_file_name = f"{month_n}-{day}-{city}.{extension}"
    return new_file_name

# %%
rename_my_file("apr-01_shanghai.txt")
# Out:
# '04-01-shanghai.txt'

# %% [markdown]
# ## Task 3

# %%
def rename_my_file(old_file_name):
    month_mapping = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
    }
    folder_name = "os-collaboration-exercise-data"
    part = old_file_name.split('_')
    month_e,day = part[0].split('-')
    city = part[1].split('.')[0]
    extension = part[1].split('.')[1]
    #print(month_e,day,city)
    month_n = month_mapping[month_e]
    new_file_name = f"{month_n}-{day}-{city}.{extension}"
    list_file_1 = [old_file_name,new_file_name]
    return list_file_1

# %%
file_list_1 = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

# %%
for i in file_list_1:
    rename_my_file(i)
    external_new_file_name = rename_my_file(i)[1]
    external_old_file_name = rename_my_file(i)[0]
    print(f'{external_old_file_name} ----> {external_new_file_name}')
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %% [markdown]
# ## Task 4

# %%
file_big_list_1 = glob.glob('os-collaboration-exercise-data\*.txt')

# %%
for i in file_big_list_1:
    rename_my_file(os.path.split(i)[-1])
    external_new_file_name = rename_my_file(os.path.split(i)[-1])[1]
    external_old_file_name = rename_my_file(os.path.split(i)[-1])[0]
    external_new_file_path = os.path.join('os-collaboration-exercise-data',external_new_file_name)
    external_old_file_path = os.path.join('os-collaboration-exercise-data',external_old_file_name)
    print(f'{external_old_file_path} ----> {external_new_file_path}')
    os.rename(external_old_file_path,external_new_file_path)
# Out:
# os-collaboration-exercise-data\apr-01_melbourne.txt ----> os-collaboration-exercise-data\04-01-melbourne.txt
# os-collaboration-exercise-data\apr-01_shanghai.txt ----> os-collaboration-exercise-data\04-01-shanghai.txt
# os-collaboration-exercise-data\apr-01_singapore.txt ----> os-collaboration-exercise-data\04-01-singapore.txt
# os-collaboration-exercise-data\apr-02_cairo.txt ----> os-collaboration-exercise-data\04-02-cairo.txt
# os-collaboration-exercise-data\apr-02_jakarta.txt ----> os-collaboration-exercise-data\04-02-jakarta.txt
# os-collaboration-exercise-data\apr-02_karachi.txt ----> os-collaboration-exercise-data\04-02-karachi.txt
# os-collaboration-exercise-data\apr-02_shanghai.txt ----> os-collaboration-exercise-data\04-02-shanghai.txt
# os-collaboration-exercise-data\apr-03_manila.txt ----> os-collaboration-exercise-data\04-03-manila.txt
# os-collaboration-exercise-data\apr-03_osaka.txt ----> os-collaboration-exercise-data\04-03-osaka.txt
# ...

# %% [markdown]
# ## Task 5

# %%
city_list = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

# %%
for city in city_list:
    path = os.path.join("os-collaboration-exercise-data",city)
    print(path)
    os.mkdir(path)
# Out:
# os-collaboration-exercise-data\Cairo
# os-collaboration-exercise-data\Dhaka
# os-collaboration-exercise-data\Jakarta
# os-collaboration-exercise-data\Karachi
# os-collaboration-exercise-data\Manila
# os-collaboration-exercise-data\Melbourne
# os-collaboration-exercise-data\Osaka
# os-collaboration-exercise-data\Shanghai
# os-collaboration-exercise-data\Singapore
# os-collaboration-exercise-data\Tokyo

# %% [markdown]
# ## Task 6

# %% [markdown]
# Since I already try the task 6 using data_back_up folder. For actual exercise, I will do every thing in task 7(which I don't need to do Cairo separately)

# %% [markdown]
# ## Task 7

# %%
city_variables = {}
for city in city_list:
    city_variables[city] = glob.glob(f"os-collaboration-exercise-data\*{city}.*")
    for i in city_variables[city]:
        print(f'copy {i} to {city}')
# Out:
# copy os-collaboration-exercise-data\01-02-cairo.txt to Cairo
# copy os-collaboration-exercise-data\01-03-cairo.txt to Cairo
# copy os-collaboration-exercise-data\01-04-cairo.txt to Cairo
# copy os-collaboration-exercise-data\01-05-cairo.txt to Cairo
# copy os-collaboration-exercise-data\01-07-cairo.txt to Cairo
# copy os-collaboration-exercise-data\01-08-cairo.txt to Cairo
# copy os-collaboration-exercise-data\01-09-cairo.txt to Cairo
# copy os-collaboration-exercise-data\01-11-cairo.txt to Cairo
# copy os-collaboration-exercise-data\01-12-cairo.txt to Cairo
# copy os-collaboration-exercise-data\01-13-cairo.txt to Cairo
# copy os-collaboration-exercise-data\01-15-cairo.txt to Cairo
# copy os-collaboration-exercise-data\01-16-cairo.txt to Cairo
# copy os-collaboration-exercise-data\01-19-cairo.txt to Cairo
# copy os-collaboration-exercise-data\01-20-cairo.txt to Cairo
# copy os-collaboration-exercise-data\01-21-cairo.txt to Cairo
# ...

# %%
city_variables = {}
for city in city_list:
    city_variables[city] = glob.glob(f"os-collaboration-exercise-data\*{city}.*")
    city_path = os.path.join("os-collaboration-exercise-data",city)
    for i in city_variables[city]:
        shutil.move(i,city_path)
